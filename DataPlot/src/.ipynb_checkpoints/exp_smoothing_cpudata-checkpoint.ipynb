# %%
# %matplotlib inline
import fileutils
import numpy as np
from matplotlib import pyplot as plt
import holtwinters as hw
from scipy import fft, arange, sqrt
from sklearn.metrics import mean_squared_error
import pandas as pd

# %%
data = pd.read_csv("D:/data/cpuRate/cpu_660404.csv")

fig = plt.figure(figsize=(12,8))
plt.plot(data.Cpu);
plt.xlim(0, 8500);

# %%
'''
Input window = 250 hours = 250*12 = 3000 
look ahead window 60 samples =  5 hours = 720min/5 = 60
one day sample = 24hours*60min /5min = 288
'''
input_window = 3000
predic_window = 60
one_day_samples = 288
real = data.Cpu[input_window:input_window+predic_window]
Y = data.Cpu[:input_window].tolist()
forecast, alpha, beta, gamma, rmse = hw.additive(Y, m=2784, fc=predic_window)

print "rmse:", rmse
print "alpha:", alpha, "beta", beta, "gamma:", gamma
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-0abb2b10ba50> in <module>()
#       7 predic_window = 60
#       8 one_day_samples = 288
# ----> 9 real = data[input_window:input_window+predic_window,1]
#      10 Y = data[:input_window,1].tolist()
#      11 forecast, alpha, beta, gamma, rmse = hw.additive(Y, m=2784, fc=predic_window)
#
# C:\Utils\Portable Python 2.7.6.1\App\lib\site-packages\pandas\core\frame.pyc in __getitem__(self, key)
#    1926         else:
#    1927             # get column
# -> 1928             return self._get_item_cache(key)
#    1929
#    1930     def _getitem_slice(self, key):
#
# C:\Utils\Portable Python 2.7.6.1\App\lib\site-packages\pandas\core\generic.pyc in _get_item_cache(self, item)
#     568             return cache[item]
#     569         except Exception:
# --> 570             values = self._data.get(item)
#     571             res = self._box_item_values(item, values)
#     572             cache[item] = res
#
# C:\Utils\Portable Python 2.7.6.1\App\lib\site-packages\pandas\core\internals.pyc in get(self, item)
#    1381
#    1382     def get(self, item):
# -> 1383         _, block = self._find_block(item)
#    1384         return block.get(item)
#    1385
#
# C:\Utils\Portable Python 2.7.6.1\App\lib\site-packages\pandas\core\internals.pyc in _find_block(self, item)
#    1523
#    1524     def _find_block(self, item):
# -> 1525         self._check_have(item)
#    1526         for i, block in enumerate(self.blocks):
#    1527             if item in block:
#
# C:\Utils\Portable Python 2.7.6.1\App\lib\site-packages\pandas\core\internals.pyc in _check_have(self, item)
#    1529
#    1530     def _check_have(self, item):
# -> 1531         if item not in self.items:
#    1532             raise KeyError('no item named %s' % com.pprint_thing(item))
#    1533
#
# C:\Utils\Portable Python 2.7.6.1\App\lib\site-packages\pandas\core\index.pyc in __contains__(self, key)
#     356
#     357     def __contains__(self, key):
# --> 358         hash(key)
#     359         # work around some kind of odd cython bug
#     360         try:
#
# TypeError: unhashable type

# %%
plt.figure(figsize=(12,8))
plt.plot(real, label='Real');
plt.plot(forecast, label='Forecast');
plt.legend();
