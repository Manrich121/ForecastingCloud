# %%
# %matplotlib inline
import fileutils
import tsutils
import numpy as np
import matplotlib.pyplot as plt
import evaluation as eval
from scipy import signal

overload_dur = 5 #samples
train_window = 3000

forecasts = np.genfromtxt("d:/data/cpu2_press/cpu_16915959.csv",delimiter=',',usecols=range(0,30)).ravel()
truevals = np.genfromtxt("d:/data/cpu2/cpu_16915959.csv", delimiter=',',skip_header=1)[:train_window+forecasts.shape[0],1]

threshold =  np.percentile(truevals, 70)

plt.figure(figsize=(12,8))
plt.plot(truevals)
plt.plot(range(3000,3000+len(forecasts)),forecasts, linewidth=1.5)
plt.hlines(threshold,0,len(truevals))
plt.show()

# %%
rmse = eval.calc_RMSE(truevals[train_window:],forecasts, print_=True)
# Out:
# RMSE =  0.0807255189253

# %%
correct, overest, underest = eval.calc_upper_lower_acc(truevals[train_window:], forecasts, print_=True)
# Out:
# Correct prediction rate = 0.125093632959
# Over-estimation rate = 0.403745318352
# Under-estimation rate = 0.471161048689

# %%
TPR, FPR = eval.calc_persample_accuracy(truevals[train_window:], forecasts, threshold, print_=True)
# Out:
#  ------------
# | 881 | 310 |
# -----------
# | 945 | 3204 |
#  ------------
# TPR =  0.482475355969
# FPR =  0.088218554354

# %%
TPR, FPR = eval.calc_overload_states_acc(truevals[train_window:], forecasts, threshold, print_=True)
# Out:
#  ------------
# | 5 | 62 |
# -----------
# | 62 | 5 |
#  ------------
# TPR =  0.0746268656716
# FPR =  0.925373134328
