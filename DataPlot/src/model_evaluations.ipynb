# %%
# %matplotlib inline
import fileutils
import tsutils
import evaluation as eval
import numpy as np
import matplotlib.pyplot as plt

'''
Results are saved to file in the following format
[RMSE, correct_rate, overest_rate, underest_rate, TPR_persample, FPR_persample, TPR_overloadstate, FPR_overloadstat]
'''
labs = ['Holtwinters', 'AutoRegression']
results = np.genfromtxt("d:/data/results/holtwinters.csv", delimiter=',')
results = np.vstack((results, np.genfromtxt("d:/data/results/autoregressive.csv", delimiter=',')))

# %% [markdown]
# ### RMSE

# %%
plt.boxplot((results[:100,0], results[100:,0]), whis=[10,90], showfliers=False, labels=labs);

# %% [markdown]
# ### Correct Prediction (within +- 10 %)

# %%
plt.boxplot((results[:100,1], results[100:,1]), whis=[10,90], showfliers=False, labels=labs);

# %% [markdown]
# ### Over-estimation rate (>10% of actual value)

# %%
plt.boxplot((results[:100,2], results[100:,2]), whis=[10,90], showfliers=False, labels=labs);

# %% [markdown]
# ### Under-estimation rate (<10% of actual value)

# %%
plt.boxplot((results[:100,3], results[100:,3]), showfliers=False, labels=labs);

# %% [markdown]
# ### True Postive Rate per sample Accuracy

# %%
plt.boxplot((results[:100,4], results[100:,4]), whis=[10,90], showfliers=False, labels=['Holtwinters', 'AutoRegression']);

# %% [markdown]
# ### False Positive Rate per sample Accuracy

# %%
plt.boxplot((results[:100,5], results[100:,5]), whis=[10,90], showfliers=False, labels=labs);

# %% [markdown]
# ### True Postive Rate for predicting the overload state

# %%
plt.boxplot((results[:100,6], results[100:,6]), whis=[10,90], showfliers=False, labels=['Holtwinters', 'AutoRegression']);

# %% [markdown]
# ### False Postive Rate for predicting the not-overload state

# %%
plt.boxplot((results[:100,7], results[100:,7]), whis=[10,90], showfliers=False, labels=labs);
