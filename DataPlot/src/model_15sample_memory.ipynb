# %%
# %matplotlib inline
import fileutils
import tsutils
import evaluation as eval
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import scipy

# %%
ma = np.genfromtxt("d:/data/results/memory_ma.csv", delimiter=',')
holtwinters = np.genfromtxt("d:/data/results/memory_holtwinters.csv", delimiter=',')
autoreg = np.genfromtxt("d:/data/results/memory_ar.csv", delimiter=',')
markov1 = np.genfromtxt("d:/data/results/memory_markov1.csv", delimiter=',')
markov2 = np.genfromtxt("d:/data/results/memory_markov2.csv", delimiter=',')
press = np.genfromtxt("d:/data/results/memory_press.csv", delimiter=',')
agile = np.genfromtxt("d:/data/results/memory_agile.csv", delimiter=',')
fnn = np.genfromtxt("d:/data/results/memory_fnn.csv", delimiter=',')
rnn = np.genfromtxt("d:/data/results/memory_rnn.csv", delimiter=',')

ma2 = np.genfromtxt("D:/15_sample_results/results/memory_ma.csv", delimiter=',')
holtwinters2 = np.genfromtxt("D:/15_sample_results/results/memory_hw.csv", delimiter=',')
autoreg2 = np.genfromtxt("D:/15_sample_results/results/memory_ar.csv", delimiter=',')
markov12 = np.genfromtxt("D:/15_sample_results/results/memory_markov1.csv", delimiter=',')
markov22 = np.genfromtxt("D:/15_sample_results/results/memory_markov2.csv", delimiter=',')
press2 = np.genfromtxt("D:/15_sample_results/results/memory_press.csv", delimiter=',')
agile2 = np.genfromtxt("D:/15_sample_results/results/memory_agile.csv", delimiter=',')
fnn2 = np.genfromtxt("D:/15_sample_results/results/memory_fnn.csv", delimiter=',')
rnn2 = np.genfromtxt("D:/15_sample_results/results/memory_rnn.csv", delimiter=',')
results = [ma, ma2, holtwinters, holtwinters2, autoreg, autoreg2, markov1, markov12, press, press2, agile, agile2, fnn, fnn2, rnn, rnn2]
labs = ['MA', 'MA*', 'HW', 'HW*', 'AR(30)', 'AR(30)*', 'Markov', 'Markov*', 'PRESS', 'PRESS*', 'Agile', 'Agile*', 'FFNN', 'FFNN*', 'RNN', 'RNN*']

# %%
def reject_outliers(data, m = 2.):
    data = np.nan_to_num(data)
    d = np.abs(data - np.median(data))
    mdev = np.median(d)
    s = d/mdev if mdev else 0.
    return data[s<m]

# %%
def calcT(x1, s1, x2, s2, n):
    sp = np.sqrt(((n-1)*s1*s1 + (n-1)*s2*s2)/(2.0*n-2))
    return (x1 - x2)/(sp*np.sqrt(2.0/n))

def calcPvalue(data1, data2, N=500):
    x1, s1 = np.mean(data1), np.std(data1)
    x2, s2 = np.mean(data2), np.std(data2)
    print 'pval=', scipy.stats.t.sf(np.abs(calcT(x1, s1, x2, s2, N)), N-1)

# %%
def calcGain(x1, x2):
    mu1, s1 = np.mean(x1), np.std(x1)
    mu2, s2 = np.mean(x2), np.std(x2)
    g = 1 - mu2/mu1
    return g

# %%
plt.figure(figsize=(12,6))
plt.xticks(horizontalalignment='left',rotation=-70, fontsize=15)
pos = [0,0.5, 1.5,2, 3,3.5, 4.5,5, 6,6.5, 7.5,8, 9,9.5, 10.5,11]
pltdic = plt.boxplot([reject_outliers(results[i][:,0]) for i in range(len(labs))], positions=pos, widths=0.3, whis=[10,90], showmeans=True, showfliers=False, labels=labs);
plt.grid()
plt.ylabel('Root Mean Squared Error', fontsize=15)
plt.title("RMSE: Comparing forecasting window lengths on Memory usage data",fontsize=15)
plt.subplots_adjust(bottom=0.2)
plt.savefig("D:/Manrich-PC/Dropbox/Dropbox/M/MThesis/masters/figs/mem_15_rmse.pdf", type='pdf')
g_means_rmse = []
for i in [0,2,4,6,8,10,12,14]:
    m =calcGain(reject_outliers(results[i][:,0]),reject_outliers(results[i+1][:,0]))
    g_means_rmse.append(m)
    calcPvalue(reject_outliers(results[i][:,0]),reject_outliers(results[i+1][:,0]),N=100)
print 'mean_gain=', np.mean(g_means_rmse)#, "std_gain", 100*np.mean(g_std_rmse)
# Out:
# pval= 0.208262863155
# pval= 0.479555612125
# pval= 0.196024749014
# pval= 0.173970626616
# pval= 0.0251577806031
# pval= 0.0496372887636
# pval= 0.00742989073081
# pval= 0.322387222783
# mean_gain= 0.0559723296265

# %%
plt.figure(figsize=(12,6))
plt.xticks(horizontalalignment='left',rotation=-70, fontsize=15)
pos = [0,0.5, 1.5,2, 3,3.5, 4.5,5, 6,6.5, 7.5,8, 9,9.5, 10.5,11]
pltdic = plt.boxplot([reject_outliers(results[i][:,1]) for i in range(len(labs))], positions=pos, widths=0.3, whis=[10,90], showmeans=True, showfliers=False, labels=labs);
plt.grid()
plt.ylabel('Correct Estimation Rate', fontsize=15)
plt.title("Correct Estimation Rate: Comparing forecasting window lengths on Memory usage data",fontsize=15)
plt.subplots_adjust(bottom=0.2)
plt.savefig("D:/Manrich-PC/Dropbox/Dropbox/M/MThesis/masters/figs/mem_15_correct.pdf", type='pdf')
gains_rmse = []
for i in [0,2,4,6,8,10,12,14]:
    gains_rmse.append(calcGain(reject_outliers(results[i][:,1]),reject_outliers(results[i+1][:,1])))
    calcPvalue(reject_outliers(results[i][:,1]),reject_outliers(results[i+1][:,1]),N=100)
print 'mean_gain=', np.mean(gains_rmse)
# Out:
# pval= 0.18243334031
# pval= 0.260049836349
# pval= 0.0924294603159
# pval= 0.00402227269343
# pval= 0.0780496411753
# pval= 0.0282549780777
# pval= 0.121752087916
# pval= 0.11892521874
# mean_gain= -0.0571555267046

# %%
plt.figure(figsize=(12,6))
plt.xticks(horizontalalignment='left',rotation=-70, fontsize=15)
pos = [0,0.5, 1.5,2, 3,3.5, 4.5,5, 6,6.5, 7.5,8, 9,9.5, 10.5,11]
pltdic = plt.boxplot([reject_outliers(0.3*results[i][:,2] + 0.7*results[i][:,3]) for i in range(len(labs))], positions=pos, showmeans=True, widths=0.3, whis=[10,90], showfliers=False, labels=labs);
plt.grid()
plt.ylabel('Estimation score', fontsize=15)
plt.title("Estimation Score: Comparing forecasting window lengths on Memory usage data",fontsize=15)
plt.subplots_adjust(bottom=0.2)
plt.savefig("D:/Manrich-PC/Dropbox/Dropbox/M/MThesis/masters/figs/mem_15_estscore.pdf", type='pdf')
gains_rmse = []
for i in [0,2,4,6,8,10,12,14]:
    gains_rmse.append(calcGain(reject_outliers(0.3*results[i][:,2] + 0.7*results[i][:,3]),reject_outliers(0.3*results[i+1][:,2] + 0.7*results[i+1][:,3])))
    calcPvalue(reject_outliers(0.3*results[i][:,2] + 0.7*results[i][:,3]),reject_outliers(0.3*results[i+1][:,2] + 0.7*results[i+1][:,3]),100)
print 'mean_gain=', np.mean(gains_rmse)
# Out:
# pval= 0.14662706298
# pval= 0.226391065025
# pval= 0.073567417695
# pval= 0.20901971193
# pval= 0.183832253491
# pval= 0.0248138767961
# pval= 0.0907236044352
# pval= 0.102383968641
# mean_gain= 0.0553636980783

# %%
plt.figure(figsize=(12,6))
plt.xticks(horizontalalignment='left',rotation=-70, fontsize=15)
pos = [0,0.5, 1.5,2, 3,3.5, 4.5,5, 6,6.5, 7.5,8, 9,9.5, 10.5,11]
pltdic = plt.boxplot([reject_outliers(results[i][:,4]/results[i][:,5]) for i in range(len(labs))], showmeans=True, positions=pos, widths=0.3, whis=[10,90], showfliers=False, labels=labs);
plt.grid()
plt.ylabel('Overload Likelihood Ratio', fontsize=15)
plt.title("OLR: Comparing forecasting window lengths on Memorr usage data",fontsize=15)
plt.subplots_adjust(bottom=0.2)
plt.savefig("D:/Manrich-PC/Dropbox/Dropbox/M/MThesis/masters/figs/mem_15_olr.pdf", type='pdf')
gains_rmse = []
for i in [0,2,4,6,8,10,12,14]:
    gains_rmse.append(calcGain(reject_outliers(results[i][:,4]/results[i][:,5]),reject_outliers(results[i+1][:,4]/results[i+1][:,5])))
    calcPvalue(reject_outliers(results[i][:,4]/results[i][:,5]),reject_outliers(results[i+1][:,4]/results[i+1][:,5]),100)
print 'mean_gain=', np.mean(gains_rmse)
# Out:
# pval= 0.0234868186943
# pval= 0.0125487858302
# pval= 0.00134436214906
# pval= 0.000186975029159
# pval= 0.002648334265
# pval= 0.00262688003893
# pval= 0.0203886812821
# pval= 0.0153199911717
# mean_gain= -0.127724793031

# %%
plt.figure(figsize=(12,6))
plt.xticks(horizontalalignment='left',rotation=-70, fontsize=15)
pos = [0,0.5, 1.5,2, 3,3.5, 4.5,5, 6,6.5, 7.5,8, 9,9.5, 10.5,11]
pltdic = plt.boxplot([reject_outliers(results[i][:,6]/results[i][:,7]) for i in range(len(labs))], showmeans=True, positions=pos, widths=0.3, whis=[10,90], showfliers=False, labels=labs);
plt.grid()
plt.ylabel('Overloaded State Likelihood Ratio', fontsize=15)
plt.title("OSLR: Comparing forecasting window lenghts on Memory usage data",fontsize=15)
plt.subplots_adjust(bottom=0.2)
plt.savefig("D:/Manrich-PC/Dropbox/Dropbox/M/MThesis/masters/figs/mem_15_oslr.pdf", type='pdf')
gains_rmse = []
for i in [0,2,4,6,8,10,12,14]:
    gains_rmse.append(calcGain(reject_outliers(results[i][:,6]/results[i][:,7]),reject_outliers(results[i+1][:,6]/results[i+1][:,7])))
    calcPvalue(reject_outliers(results[i][:,6]/results[i][:,7]),reject_outliers(results[i+1][:,6]/results[i+1][:,7]),100)
print 'mean_gain=', np.mean(gains_rmse)
# Out:
# pval= 0.031729827009
# pval= 5.67559325429e-07
# pval= 7.18515436048e-14
# pval= 8.30470780016e-32
# pval= 6.84782063092e-26
# pval= 2.17945063738e-26
# pval= 1.88353679142e-09
# pval= 8.64506684198e-09
# mean_gain= -0.584566176457

# %%
for i in [0,2,4,6,8,10,12,14]:
    print labs[i],labs[i+1]
    calcPvalue(reject_outliers(results[i][:,0]),reject_outliers(results[i+1][:,0]),N=100)
# Out:
# MA MA*
# pval= 0.208262863155
# HW HW*
# pval= 0.479555612125
# AR(30) AR(30)*
# pval= 0.196024749014
# Markov Markov*
# pval= 0.173970626616
# PRESS PRESS*
# pval= 0.0251577806031
# Agile Agile*
# pval= 0.0496372887636
# FFNN FFNN*
# pval= 0.00742989073081
# RNN RNN*
# pval= 0.322387222783
