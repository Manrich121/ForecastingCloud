# %%
# %matplotlib inline
import fileutils
import numpy as np
from matplotlib import pyplot as plt
import statsmodels.api as sm
from pandas.tools.plotting import lag_plot
import pandas

# %%
data1 = np.genfromtxt("d:/data/cpuRate/cpuRate_660404.csv", delimiter=',', usecols=(0,1))

fig = plt.figure(figsize=(12,8))
plt.plot(data1[:,1]);
plt.xlim(0, 8500);

# %%
plt.figure(figsize=(12,8));
series = pandas.Series(data1[:,1])
lag_plot(series);

# %%
data2 = np.genfromtxt("d:/data/cpuRate/cpuRate_4469371300.csv", delimiter=',', usecols=(0,1))

fig = plt.figure(figsize=(12,8))
plt.plot(data2[:,1]);
plt.xlim(0, 8500);

# %%
plt.figure(figsize=(12,8));
series = pandas.Series(data2[:,1])
lag_plot(series);

# %%
data = np.genfromtxt("d:/data/cpuRate/cpuRate_4815459946.csv", delimiter=',', usecols=(0,1))

fig = plt.figure(figsize=(12,8))
plt.plot(data[:,1]);
plt.xlim(0, 8500);

# %%
plt.figure(figsize=(12,8));
series = pandas.Series(data[:,1])
lag_plot(series);
