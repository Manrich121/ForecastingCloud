# %%
# %matplotlib inline
import fileutils
import tsutils
import evaluation as eval
import numpy as np
import matplotlib.pyplot as plt

# %%
forecasts = np.genfromtxt("D:/Wikipage data/pageviews_markov1/view_af",delimiter=',').ravel()
truevals = np.genfromtxt("D:/Wikipage data/pageviews/view_af")
truevals = truevals/np.max(truevals)
plt.plot(truevals)
plt.plot(range(3000,3000+len(forecasts)), forecasts)
