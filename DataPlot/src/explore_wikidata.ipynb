# %%
# %matplotlib inline
import fileutils
import tsutils
import evaluation as eval
import numpy as np
import matplotlib.pyplot as plt

# %%
forecasts = np.genfromtxt("D:/Wikipage data/pageviews_agile/view_af",delimiter=',').ravel()
truevals = np.genfromtxt("D:/Wikipage data/pageviews/view_af")
truevals = truevals/np.max(truevals)

plt.figure(figsize=(12,8))
plt.plot(truevals)
plt.plot(range(3000,3000+len(forecasts)), forecasts)
# plt.show()

# %%
print truevals.shape
# Out:
# (8714,)
