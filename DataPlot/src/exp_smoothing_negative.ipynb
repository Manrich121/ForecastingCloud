# %%
# %matplotlib inline
import fileutils
import tsutils
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.metrics import mean_squared_error

# %%
forecasts = np.genfromtxt("d:/data/cpu_exp_smooting_forecasts/cpu_1095481.csv",delimiter=',').ravel()
truevals = np.genfromtxt("d:/data/cpuRate/cpu_1095481.csv", delimiter=',',skip_header=1)[:,1]

# %%
plt.figure(figsize=(12,8))
plt.plot(truevals)
plt.plot(range(3000,3000+len(forecasts)),forecasts)

# %%
print mean_squared_error(truevals[-len(forecasts):],forecasts)
# Out:
# 0.0170349320309

# %%
minVal = np.percentile(truevals,5)
forecasts[np.argwhere(forecasts<0)] = minVal

# %%
plt.figure(figsize=(12,8))
plt.plot(truevals)
plt.plot(range(3000,3000+len(forecasts)),forecasts)

# %%
print mean_squared_error(truevals[-len(forecasts):],forecasts)
# Out:
# 0.0132571124313
