# %%
# %matplotlib inline
# from __future__ import print_function

import numpy as np
import scipy
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import pyplot as plt
import evaluation as eval

from pybrain.datasets import SupervisedDataSet
from pybrain.tools.shortcuts import buildNetwork
from pybrain.supervised.trainers import BackpropTrainer
from pybrain.structure.modules import SigmoidLayer

# %%
data = np.genfromtxt("d:/data/cpuRate/cpu_905814.csv",skip_header=1, delimiter=',',usecols=(1))
threshold =  np.percentile(data, 70)
plt.figure(figsize=(12,8))
plt.plot(data)

# %%
TRAIN = 1000
VALID = 100
TEST = 100
INPUT_SIZE = 30
train, valid, test = data[:TRAIN], data[TRAIN-INPUT_SIZE:TRAIN+VALID], data[TRAIN-INPUT_SIZE+VALID:TRAIN+VALID+TEST]

# %%
plt.plot(train)

# %%
trainds = SupervisedDataSet(INPUT_SIZE, 1)
testds = SupervisedDataSet(INPUT_SIZE, 1)
validds = SupervisedDataSet(INPUT_SIZE, 1)

for i in range(INPUT_SIZE,train.shape[0]):
    trainds.appendLinked(train[i-INPUT_SIZE:i],train[i])

for i in range(INPUT_SIZE,test.shape[0]):
    testds.appendLinked(test[i-INPUT_SIZE:i],test[i])

for i in range(INPUT_SIZE,valid.shape[0]):
    validds.appendLinked(valid[i-INPUT_SIZE:i],valid[i])

# %%
HIDDEN = [5, 10, 15, 20]
ETA = [0.0001, 0.001, 0.01, 0.1]
LAMDA = [0.0, 0.01, 0.1, 1.0]
EPOCHS = 25

# %%
nets = []
rmse = []
correct = []
hyperparams = []
truevals = validds['target']
for hidden in HIDDEN:
    for eta in ETA:
        for lmda in LAMDA:
            epoch = EPOCHS*-1.0*np.log10(eta)
            print hidden, eta, lmda, epoch
            hyperparams.append([hidden, eta, lmda, epoch])
            net = buildNetwork(INPUT_SIZE, hidden, 1,  bias=True)
            nets.append(net)
            trainer = BackpropTrainer(net, trainds, learningrate=eta, weightdecay=lmda, shuffle=False)
            trainer.trainUntilConvergence(maxEpochs=epoch, validationData=validds)
            
            pred = net.activateOnDataset(validds)
            rmse.append(eval.calc_RMSE(truevals, pred, print_=True))
            correct.append(eval.calc_upper_lower_acc(truevals, pred, print_=True))
# Out:
# 5 0.0001 0.0 100.0
# RMSE =
#  0.0774595701577
# Correct prediction rate = [ 0.3]
# Over-estimation rate = [ 0.29]
# Under-estimation rate = [ 0.41]
# 5 0.0001 0.01 100.0
# RMSE =
#  0.156279470256
# Correct prediction rate = [ 0.09]
# Over-estimation rate = [ 0.4]
# Under-estimation rate = [ 0.51]
# 5 0.0001 0.1 100.0
# RMSE =
#  0.0586568741485
# Correct prediction rate = [ 0.37]
# Over-estimation rate = [ 0.16]
# Under-estimation rate = [ 0.47]
# 5 0.0001 1.0 100.0
# RMSE =
#  0.0915299090991
# Correct prediction rate = [ 0.01]
# Over-estimation rate = [ 0.04]
# Under-estimation rate = [ 0.95]
# 5 0.001 0.0 75.0
# RMSE =
#  0.0746387128168
# Correct prediction rate = [ 0.23]
# Over-estimation rate = [ 0.18]
# Under-estimation rate = [ 0.59]
# 5 0.001 0.01 75.0
# RMSE =
#  0.0565096417688
# Correct prediction rate = [ 0.28]
# Over-estimation rate = [ 0.25]
# Under-estimation rate = [ 0.47]
# 5 0.001 0.1 75.0
# RMSE =
#  0.0573918647658
# Correct prediction rate = [ 0.41]
# Over-estimation rate = [ 0.08]
# Under-estimation rate = [ 0.51]
# 5 0.001 1.0 75.0
# RMSE =
#  0.101164039578
# Correct prediction rate = [ 0.01]
# Over-estimation rate = [ 0.03]
# Under-estimation rate = [ 0.96]
# 5 0.01 0.0 50.0
# RMSE =
#  0.0691521225363
# Correct prediction rate = [ 0.26]
# Over-estimation rate = [ 0.08]
# Under-estimation rate = [ 0.66]
# 5 0.01 0.01 50.0
# RMSE =
#  0.066711162784
# Correct prediction rate = [ 0.21]
# Over-estimation rate = [ 0.05]
# Under-estimation rate = [ 0.74]
# 5 0.01 0.1 50.0
# RMSE =
#  0.0654180513393
# Correct prediction rate = [ 0.33]
# Over-estimation rate = [ 0.06]
# Under-estimation rate = [ 0.61]
# 5 0.01 1.0 50.0
# RMSE =
#  0.113923313093
# Correct prediction rate = [ 0.03]
# Over-estimation rate = [ 0.01]
# Under-estimation rate = [ 0.96]
# 5 0.1 0.0 25.0
# RMSE =
#  0.0530394324497
# Correct prediction rate = [ 0.35]
# Over-estimation rate = [ 0.12]
# Under-estimation rate = [ 0.53]
# 5 0.1 0.01 25.0
# RMSE =
#  0.0516414783448
# Correct prediction rate = [ 0.5]
# Over-estimation rate = [ 0.11]
# Under-estimation rate = [ 0.39]
# 5 0.1 0.1 25.0
# RMSE =
#  0.0548937127625
# Correct prediction rate = [ 0.47]
# Over-estimation rate = [ 0.09]
# Under-estimation rate = [ 0.44]
# 5 0.1 1.0 25.0
# RMSE =
#  0.0846469906662
# Correct prediction rate = [ 0.03]
# Over-estimation rate = [ 0.04]
# Under-estimation rate = [ 0.93]
# 10 0.0001 0.0 100.0
# RMSE =
#  0.190334628126
# Correct prediction rate = [ 0.14]
# Over-estimation rate = [ 0.48]
# Under-estimation rate = [ 0.38]
# 10 0.0001 0.01 100.0
# RMSE =
#  0.0902345203856
# Correct prediction rate = [ 0.26]
# Over-estimation rate = [ 0.29]
# Under-estimation rate = [ 0.45]
# 10 0.0001 0.1 100.0
# RMSE =
#  0.0527053186617
# Correct prediction rate = [ 0.39]
# Over-estimation rate = [ 0.17]
# Under-estimation rate = [ 0.44]
# 10 0.0001 1.0 100.0
# RMSE =
#  0.0644647459063
# Correct prediction rate = [ 0.28]
# Over-estimation rate = [ 0.08]
# Under-estimation rate = [ 0.64]
# 10 0.001 0.0 75.0
# RMSE =
#  0.0870710410281
# Correct prediction rate = [ 0.22]
# Over-estimation rate = [ 0.41]
# Under-estimation rate = [ 0.37]
# 10 0.001 0.01 75.0
# RMSE =
#  0.0691595353471
# Correct prediction rate = [ 0.3]
# Over-estimation rate = [ 0.38]
# Under-estimation rate = [ 0.32]
# 10 0.001 0.1 75.0
# RMSE =
#  0.0568533079994
# Correct prediction rate = [ 0.39]
# Over-estimation rate = [ 0.07]
# Under-estimation rate = [ 0.54]
# 10 0.001 1.0 75.0
# RMSE =
#  0.065312931122
# Correct prediction rate = [ 0.27]
# Over-estimation rate = [ 0.08]
# Under-estimation rate = [ 0.65]
# 10 0.01 0.0 50.0
# RMSE =
#  0.061376571253
# Correct prediction rate = [ 0.27]
# Over-estimation rate = [ 0.2]
# Under-estimation rate = [ 0.53]
# 10 0.01 0.01 50.0
# RMSE =
#  0.0671366451202
# Correct prediction rate = [ 0.2]
# Over-estimation rate = [ 0.05]
# Under-estimation rate = [ 0.75]
# 10 0.01 0.1 50.0
# RMSE =
#  0.0603725059554
# Correct prediction rate = [ 0.36]
# Over-estimation rate = [ 0.06]
# Under-estimation rate = [ 0.58]
# 10 0.01 1.0 50.0
# RMSE =
#  0.0936767315513
# Correct prediction rate = [ 0.02]
# Over-estimation rate = [ 0.03]
# Under-estimation rate = [ 0.95]
# 10 0.1 0.0 25.0
# RMSE =
#  0.0601014958555
# Correct prediction rate = [ 0.23]
# Over-estimation rate = [ 0.67]
# Under-estimation rate = [ 0.1]
# 10 0.1 0.01 25.0
# RMSE =
#  0.047633973081
# Correct prediction rate = [ 0.45]
# Over-estimation rate = [ 0.25]
# Under-estimation rate = [ 0.3]
# 10 0.1 0.1 25.0
# RMSE =
#  0.047148376629
# Correct prediction rate = [ 0.44]
# Over-estimation rate = [ 0.3]
# Under-estimation rate = [ 0.26]
# 10 0.1 1.0 25.0
# RMSE =
#  0.0876252526928
# Correct prediction rate = [ 0.01]
# Over-estimation rate = [ 0.04]
# Under-estimation rate = [ 0.95]
# 15 0.0001 0.0 100.0
# RMSE =
#  0.143010105261
# Correct prediction rate = [ 0.06]
# Over-estimation rate = [ 0.28]
# Under-estimation rate = [ 0.66]
# 15 0.0001 0.01 100.0
# RMSE =
#  0.175456524081
# Correct prediction rate = [ 0.18]
# Over-estimation rate = [ 0.42]
# Under-estimation rate = [ 0.4]
# 15 0.0001 0.1 100.0
# RMSE =
#  0.0733665493327
# Correct prediction rate = [ 0.19]
# Over-estimation rate = [ 0.26]
# Under-estimation rate = [ 0.55]
# 15 0.0001 1.0 100.0
# RMSE =
#  0.0740005981964
# Correct prediction rate = [ 0.09]
# Over-estimation rate = [ 0.05]
# Under-estimation rate = [ 0.86]
# 15 0.001 0.0 75.0
# RMSE =
#  0.120101895918
# Correct prediction rate = [ 0.13]
# Over-estimation rate = [ 0.24]
# Under-estimation rate = [ 0.63]
# 15 0.001 0.01 75.0
# RMSE =
#  0.0603164891519
# Correct prediction rate = [ 0.33]
# Over-estimation rate = [ 0.23]
# Under-estimation rate = [ 0.44]
# 15 0.001 0.1 75.0
# RMSE =
#  0.0595288732921
# Correct prediction rate = [ 0.4]
# Over-estimation rate = [ 0.09]
# Under-estimation rate = [ 0.51]
# 15 0.001 1.0 75.0
# RMSE =
#  0.0728863145778
# Correct prediction rate = [ 0.12]
# Over-estimation rate = [ 0.05]
# Under-estimation rate = [ 0.83]
# 15 0.01 0.0 50.0
# RMSE =
#  0.051557812214
# Correct prediction rate = [ 0.32]
# Over-estimation rate = [ 0.5]
# Under-estimation rate = [ 0.18]
# 15 0.01 0.01 50.0
# RMSE =
#  0.05774217573
# Correct prediction rate = [ 0.4]
# Over-estimation rate = [ 0.08]
# Under-estimation rate = [ 0.52]
# 15 0.01 0.1 50.0
# RMSE =
#  0.0640544003283
# Correct prediction rate = [ 0.26]
# Over-estimation rate = [ 0.05]
# Under-estimation rate = [ 0.69]
# 15 0.01 1.0 50.0
# RMSE =
#  0.0879464898715
# Correct prediction rate = [ 0.01]
# Over-estimation rate = [ 0.04]
# Under-estimation rate = [ 0.95]
# 15 0.1 0.0 25.0
# RMSE =
#  0.145056696655
# Correct prediction rate = [ 0.11]
# Over-estimation rate = [ 0.15]
# Under-estimation rate = [ 0.74]
# 15 0.1 0.01 25.0
# RMSE =
#  0.0480286607151
# Correct prediction rate = [ 0.33]
# Over-estimation rate = [ 0.48]
# Under-estimation rate = [ 0.19]
# 15 0.1 0.1 25.0
# RMSE =
#  0.0471719123926
# Correct prediction rate = [ 0.44]
# Over-estimation rate = [ 0.3]
# Under-estimation rate = [ 0.26]
# 15 0.1 1.0 25.0
# RMSE =
#  0.0680783755499
# Correct prediction rate = [ 0.18]
# Over-estimation rate = [ 0.05]
# Under-estimation rate = [ 0.77]
# 20 0.0001 0.0 100.0
# RMSE =
#  0.198752824005
# Correct prediction rate = [ 0.12]
# Over-estimation rate = [ 0.41]
# Under-estimation rate = [ 0.47]
# 20 0.0001 0.01 100.0
# RMSE =
#  0.181404431341
# Correct prediction rate = [ 0.09]
# Over-estimation rate = [ 0.35]
# Under-estimation rate = [ 0.56]
# 20 0.0001 0.1 100.0
# RMSE =
#  0.0794536514088
# Correct prediction rate = [ 0.21]
# Over-estimation rate = [ 0.27]
# Under-estimation rate = [ 0.52]
# 20 0.0001 1.0 100.0
# RMSE =
#  0.0683824658599
# Correct prediction rate = [ 0.18]
# Over-estimation rate = [ 0.05]
# Under-estimation rate = [ 0.77]
# 20 0.001 0.0 75.0
# RMSE =
#  0.15489345736
# Correct prediction rate = [ 0.07]
# Over-estimation rate = [ 0.41]
# Under-estimation rate = [ 0.52]
# 20 0.001 0.01 75.0
# RMSE =
#  0.081230359772
# Correct prediction rate = [ 0.27]
# Over-estimation rate = [ 0.24]
# Under-estimation rate = [ 0.49]
# 20 0.001 0.1 75.0
# RMSE =
#  0.0562710017667
# Correct prediction rate = [ 0.41]
# Over-estimation rate = [ 0.09]
# Under-estimation rate = [ 0.5]
# 20 0.001 1.0 75.0
# RMSE =
#  0.0775496442248
# Correct prediction rate = [ 0.06]
# Over-estimation rate = [ 0.04]
# Under-estimation rate = [ 0.9]
# 20 0.01 0.0 50.0
# RMSE =
#  0.0689126759605
# Correct prediction rate = [ 0.26]
# Over-estimation rate = [ 0.14]
# Under-estimation rate = [ 0.6]
# 20 0.01 0.01 50.0
# RMSE =
#  0.0584333367796
# Correct prediction rate = [ 0.38]
# Over-estimation rate = [ 0.07]
# Under-estimation rate = [ 0.55]
# 20 0.01 0.1 50.0
# RMSE =
#  0.0527806181138
# Correct prediction rate = [ 0.46]
# Over-estimation rate = [ 0.07]
# Under-estimation rate = [ 0.47]
# 20 0.01 1.0 50.0
# RMSE =
#  0.0805997190423
# Correct prediction rate = [ 0.05]
# Over-estimation rate = [ 0.04]
# Under-estimation rate = [ 0.91]
# 20 0.1 0.0 25.0
# RMSE =
#  0.0701345105094
# Correct prediction rate = [ 0.28]
# Over-estimation rate = [ 0.62]
# Under-estimation rate = [ 0.1]
# 20 0.1 0.01 25.0
# RMSE =
#  0.0482260171896
# Correct prediction rate = [ 0.33]
# Over-estimation rate = [ 0.48]
# Under-estimation rate = [ 0.19]
# 20 0.1 0.1 25.0
# RMSE =
#  0.0491021536374
# Correct prediction rate = [ 0.29]
# Over-estimation rate = [ 0.53]
# Under-estimation rate = [ 0.18]
# 20 0.1 1.0 25.0
# RMSE =
#  0.0494637520609
# Correct prediction rate = [ 0.48]
# Over-estimation rate = [ 0.17]
# Under-estimation rate = [ 0.35]

# %%
correct = np.array(correct).reshape(64,3)

# %%
rmse_min_idx = np.argmin(rmse)
print hyperparams[rmse_min_idx]
print rmse[rmse_min_idx]
print correct[rmse_min_idx,:]
best_rmse_net = nets[rmse_min_idx]
# Out:
# [10, 0.1, 0.1, 25.0]
# 0.047148376629
# [ 0.44  0.3   0.26]

# %%
correct_max_idx= np.argmax(correct[:,0])
print hyperparams[correct_max_idx]
print rmse[correct_max_idx]
print correct[correct_max_idx,:]
best_correct_net = nets[correct_max_idx]
# Out:
# [5, 0.1, 0.01, 25.0]
# 0.0516414783448
# [ 0.5   0.11  0.39]

# %%
# trainer = BackpropTrainer(ffnet, trainds, learningrate=0.0001, weightdecay=0.01, shuffle=False)
# train_err, valid_err = trainer.trainUntilConvergence(maxEpochs=50, validationData=validds)

# %%
# SPLIT = 10
# plt.figure()
# plt.plot(train_err[:SPLIT])
# plt.plot(valid_err[:SPLIT])
# plt.figure()
# plt.plot(train_err[SPLIT:])
# plt.plot(valid_err[SPLIT:])

# %% [markdown]
# ## Training Predictions

# %%
pred = best_corret_net.activateOnDataset(trainds)
truevals = trainds['target']
eval.calc_RMSE(truevals, pred, print_=True)
eval.calc_upper_lower_acc(truevals, pred, print_=True)

plt.figure(figsize=(12,8))
plt.plot(truevals[-100:])
plt.plot(pred[-100:], '-o')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-b9a9c38f6b62> in <module>()
# ----> 1 pred = best_corret_net.activateOnDataset(trainds)
#       2 truevals = trainds['target']
#       3 eval.calc_RMSE(truevals, pred, print_=True)
#       4 eval.calc_upper_lower_acc(truevals, pred, print_=True)
#       5
#
# NameError: name 'best_corret_net' is not defined

# %% [markdown]
# ## Validation Predictions

# %%
pred = best_rmse_net.activateOnDataset(validds)
truevals = validds['target']
eval.calc_RMSE(truevals, pred, print_=True)
eval.calc_upper_lower_acc(truevals, pred, print_=True)

plt.figure(figsize=(12,8))
plt.plot(truevals)
plt.plot(pred, '-o')

# %% [markdown]
# ## Testing Predictions

# %%
pred = best_rmse_net.activateOnDataset(testds)
truevals = testds['target']
eval.calc_RMSE(truevals, pred, print_=True)
eval.calc_upper_lower_acc(truevals, pred, print_=True)

plt.figure(figsize=(12,8))
plt.plot(truevals)
plt.plot(pred, '-o')

# %%
# from pybrain.tools.customxml.networkwriter import NetworkWriter
# NetworkWriter.writeToFile(best_rmse_net, 'cpu_905814.xml')
